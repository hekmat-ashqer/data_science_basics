# %% [markdown]
# <a href="https://colab.research.google.com/github/hekmat-ashqer/data_science_basics/blob/main/dataframe_csv_4_2_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import pandas
import pandas as pd
# save file path
fname = "/content/drive/MyDrive/CodingDojo/01-Fundamentals/Week02/Data/Our Bake Sale [Loading Data Vers] - Day 4 Sales.csv"

# %%
# load in the data as a pandas dataframe
df = pd.read_csv(fname)

# %%
df
# Out:
#                     Item  Student                        Packaging  Price  \
# 0                brownie     Hugo  Individually Wrapped  (Plastic)   2.25
# 1                 cookie    Sally  Individually Wrapped  (Plastic)   1.25
# 2                   cake  Martina            Boxed (Clear Plastic)   9.50
# 3                cupcake      Joe                Boxed (Cardboard)   3.50
# 4                  fudge     Hugo      Individually Wrapped (Foil)   3.00
# 5           banana bread     Mark      Individually Wrapped (Foil)   2.75
# 6                  torte     Jade            Boxed (Clear Plastic)  10.50
# 7                  scone     Jade  Individually Wrapped  (Plastic)   2.00
# 8                 muffin     Anne      Individually Wrapped (Foil)   1.50
# 9   rice krispies treats  Martina  Individually Wrapped  (Plastic)   1.25
# 10             apple pie    Sally                  Box (Cardboard)  10.00
# 11          key lime pie  Martina                  Box (Cardboard)   9.50
#
#     Expense  Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# 0      0.25                     17                     19
# 1      0.50                     40                     32
# 2      5.00                      1                      2
# 3      0.75                     10                     14
# 4      1.00                      0                     20
# 5      0.50                      0                     10
# 6      5.50                      0                      5
# 7      1.25                      0                      8
# 8      0.75                      0                      3
# 9      0.25                      0                      0
# 10     4.00                      0                      0
# 11     4.50                      0                      0
#
#     Quantity Sold (Day 3)  Quantity Sold (Day 4)
# 0                      25                     25
# 1                      38                     38
# 2                       0                      0
# 3                      12                     12
# 4                      22                     22
# 5                      13                     13
# 6                       7                      7
# 7                      10                     10
# 8                       4                      4
# 9                      10                     30
# 10                      2                      3
# 11                      3                      3

# %%
# preview the first five rows
df.head()
# Out:
#       Item  Student                        Packaging  Price  Expense  \
# 0  brownie     Hugo  Individually Wrapped  (Plastic)   2.25     0.25
# 1   cookie    Sally  Individually Wrapped  (Plastic)   1.25     0.50
# 2     cake  Martina            Boxed (Clear Plastic)   9.50     5.00
# 3  cupcake      Joe                Boxed (Cardboard)   3.50     0.75
# 4    fudge     Hugo      Individually Wrapped (Foil)   3.00     1.00
#
#    Quantity Sold (Day 1)  Quantity Sold (Day 2)  Quantity Sold (Day 3)  \
# 0                     17                     19                     25
# 1                     40                     32                     38
# 2                      1                      2                      0
# 3                     10                     14                     12
# 4                      0                     20                     22
#
#    Quantity Sold (Day 4)
# 0                     25
# 1                     38
# 2                      0
# 3                     12
# 4                     22

# %%
# Preview the last 5 rows
df.tail()
# Out:
#                     Item  Student                        Packaging  Price  \
# 7                  scone     Jade  Individually Wrapped  (Plastic)   2.00
# 8                 muffin     Anne      Individually Wrapped (Foil)   1.50
# 9   rice krispies treats  Martina  Individually Wrapped  (Plastic)   1.25
# 10             apple pie    Sally                  Box (Cardboard)  10.00
# 11          key lime pie  Martina                  Box (Cardboard)   9.50
#
#     Expense  Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# 7      1.25                      0                      8
# 8      0.75                      0                      3
# 9      0.25                      0                      0
# 10     4.00                      0                      0
# 11     4.50                      0                      0
#
#     Quantity Sold (Day 3)  Quantity Sold (Day 4)
# 7                      10                     10
# 8                       4                      4
# 9                      10                     30
# 10                      2                      3
# 11                      3                      3

# %%
# Obtain a summary table for each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Item                   12 non-null     object
#  1   Student                12 non-null     object
#  2   Packaging              12 non-null     object
#  3   Price                  12 non-null     float64
#  4   Expense                12 non-null     float64
#  5   Quantity Sold (Day 1)  12 non-null     int64
#  6   Quantity Sold (Day 2)  12 non-null     int64
#  7   Quantity Sold (Day 3)  12 non-null     int64
#  8   Quantity Sold (Day 4)  12 non-null     int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 992.0+ bytes

# %%
# Save the url surround by quotes
url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQNX3oBeyee-rQEulninLyZoBUy3JVUy3wsGkPRl-G-mbjh5iItwBfezeGkDHnwtxnLneBX3Ylm1c64/pub?gid=860339357&single=true&output=csv"
# Read in data from url
df_url = pd.read_csv(url)
# Preview the first five rows
df_url.head()
# Out:
#       Item  Student                        Packaging  Price  Expense  \
# 0  brownie     Hugo  Individually Wrapped  (Plastic)   2.25     0.25
# 1   cookie    Sally  Individually Wrapped  (Plastic)   1.25     0.50
# 2     cake  Martina            Boxed (Clear Plastic)   9.50     5.00
# 3  cupcake      Joe                Boxed (Cardboard)   3.50     0.75
# 4    fudge     Hugo      Individually Wrapped (Foil)   3.00     1.00
#
#    Quantity Sold (Day 1)  Quantity Sold (Day 2)  Quantity Sold (Day 3)  \
# 0                     17                     19                     25
# 1                     40                     32                     38
# 2                      1                      2                      0
# 3                     10                     14                     12
# 4                      0                     20                     22
#
#    Quantity Sold (Day 4)
# 0                     25
# 1                     38
# 2                      0
# 3                     12
# 4                     22

# %%
# Preview the fist 5 rows of the dataframe from previous lesson
df.head()
# Out:
#       Item  Student                        Packaging  Price  Expense  \
# 0  brownie     Hugo  Individually Wrapped  (Plastic)   2.25     0.25
# 1   cookie    Sally  Individually Wrapped  (Plastic)   1.25     0.50
# 2     cake  Martina            Boxed (Clear Plastic)   9.50     5.00
# 3  cupcake      Joe                Boxed (Cardboard)   3.50     0.75
# 4    fudge     Hugo      Individually Wrapped (Foil)   3.00     1.00
#
#    Quantity Sold (Day 1)  Quantity Sold (Day 2)  Quantity Sold (Day 3)  \
# 0                     17                     19                     25
# 1                     40                     32                     38
# 2                      1                      2                      0
# 3                     10                     14                     12
# 4                      0                     20                     22
#
#    Quantity Sold (Day 4)
# 0                     25
# 1                     38
# 2                      0
# 3                     12
# 4                     22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Item                   12 non-null     object
#  1   Student                12 non-null     object
#  2   Packaging              12 non-null     object
#  3   Price                  12 non-null     float64
#  4   Expense                12 non-null     float64
#  5   Quantity Sold (Day 1)  12 non-null     int64
#  6   Quantity Sold (Day 2)  12 non-null     int64
#  7   Quantity Sold (Day 3)  12 non-null     int64
#  8   Quantity Sold (Day 4)  12 non-null     int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 992.0+ bytes

# %%
# Insert the new column
df.insert(5, 'Profit per Item', df['Price'] - df["Expense"]  )
# Verify the result
df.head()
# Out:
#          Student                        Packaging  Price  Expense  \
# Item
# brownie     Hugo  Individually Wrapped  (Plastic)   2.25     0.25
# cookie     Sally  Individually Wrapped  (Plastic)   1.25     0.50
# cake     Martina            Boxed (Clear Plastic)   9.50     5.00
# cupcake      Joe                Boxed (Cardboard)   3.50     0.75
# fudge       Hugo      Individually Wrapped (Foil)   3.00     1.00
#
#          Quantity Sold (Day 1)  Profit per Item  Quantity Sold (Day 2)  \
# Item
# brownie                     17             2.00                     19
# cookie                      40             0.75                     32
# cake                         1             4.50                      2
# cupcake                     10             2.75                     14
# fudge                        0             2.00                     20
#
#          Quantity Sold (Day 3)  Quantity Sold (Day 4)  \
# Item
# brownie                     25                     25
# cookie                      38                     38
# cake                         0                      0
# cupcake                     12                     12
# fudge                       22                     22
#
#          Cumulative Quantity (Day 4)
# Item
# brownie                           86
# cookie                           148
# cake                               3
# cupcake                           48
# fudge                             64

# %%
fname_out ='/content/drive/MyDrive/CodingDojo/01-Fundamentals/Week02/Data/bake-sale-data.csv'
df.to_csv(fname_out, index=False)

# %%
# Review: slicing 1 column
df["Item"]
# Out:
# 0                  brownie
# 1                   cookie
# 2                     cake
# 3                  cupcake
# 4                    fudge
# 5             banana bread
# 6                    torte
# 7                    scone
# 8                   muffin
# 9     rice krispies treats
# 10               apple pie
# 11            key lime pie
# Name: Item, dtype: object

# %%
# Review: slicing more than 1 column
df[["Item", "Student"]]
# Out:
#                     Item  Student
# 0                brownie     Hugo
# 1                 cookie    Sally
# 2                   cake  Martina
# 3                cupcake      Joe
# 4                  fudge     Hugo
# 5           banana bread     Mark
# 6                  torte     Jade
# 7                  scone     Jade
# 8                 muffin     Anne
# 9   rice krispies treats  Martina
# 10             apple pie    Sally
# 11          key lime pie  Martina

# %%
# Slice the row with cake at index 2
df.loc[2]
df.loc[[2]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-9d7214a19203> in <cell line: 2>()
#       1 # Slice the row with cake at index 2
# ----> 2 df.loc[2]
#       3 df.loc[[2]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1310         # fall thru to straight lookup
#    1311         self._validate_key(key, axis)
# -> 1312         return self._get_label(key, axis=axis)
#    1313
#    1314     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1258     def _get_label(self, label, axis: int):
#    1259         # GH#5567 this will fail if the label is not present in the axis.
# -> 1260         return self.obj.xs(label, axis=axis)
#    1261
#    1262     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4054                     new_index = index[loc]
#    4055         else:
# -> 4056             loc = index.get_loc(key)
#    4057
#    4058             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 2

# %%
# Set the index
df = df.set_index("Item")
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-1c524a0dadb6> in <cell line: 2>()
#       1 # Set the index
# ----> 2 df = df.set_index("Item")
#       3 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['Item'] are in the columns"

# %%
df.loc[['cake']]
# Slice multiple rows using a list
df.loc[['cake','brownie']]
# Out:
#          Student                        Packaging  Price  Expense  \
# Item
# cake     Martina            Boxed (Clear Plastic)   9.50     5.00
# brownie     Hugo  Individually Wrapped  (Plastic)   2.25     0.25
#
#          Profit per Item  Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# Item
# cake                 4.5                      1                      2
# brownie              2.0                     17                     19
#
#          Quantity Sold (Day 3)  Quantity Sold (Day 4)
# Item
# cake                         0                      0
# brownie                     25                     25

# %%
# Slice the muffin row and Price column
df.loc["muffin",'Price']
# Slice Price and Student for muffin
df.loc["muffin", ["Price","Student"]]
# Out:
# Price       1.5
# Student    Anne
# Name: muffin, dtype: object

# %%
# Slice multiple rows and columns
df.loc[ ['muffin','scone','banana bread'], ['Price','Expense','Student']]
# Out:
#               Price  Expense Student
# Item
# muffin         1.50     0.75    Anne
# scone          2.00     1.25    Jade
# banana bread   2.75     0.50    Mark

# %%
# Save lists of rows
rows_to_slice =  ['muffin','scone','banana bread']
# Save list of columns
cols_to_slice =  ['Price','Expense','Student']
# Use variables of lists to slice
df.loc[rows_to_slice, cols_to_slice]
# Out:
#               Price  Expense Student
# Item
# muffin         1.50     0.75    Anne
# scone          2.00     1.25    Jade
# banana bread   2.75     0.50    Mark

# %%
df["Price"]
# Selet all rows for the Price Column
df.loc[:, 'Price']
# Out:
# Item
# brownie                  2.25
# cookie                   1.25
# cake                     9.50
# cupcake                  3.50
# fudge                    3.00
# banana bread             2.75
# torte                   10.50
# scone                    2.00
# muffin                   1.50
# rice krispies treats     1.25
# apple pie               10.00
# key lime pie             9.50
# Name: Price, dtype: float64

# %%
# Slice all rows for mulitple columns
df.loc[:, ["Price","Expense"]]
# Out:
#                       Price  Expense
# Item
# brownie                2.25     0.25
# cookie                 1.25     0.50
# cake                   9.50     5.00
# cupcake                3.50     0.75
# fudge                  3.00     1.00
# banana bread           2.75     0.50
# torte                 11.50     5.50
# scone                  2.00     1.25
# muffin                 1.50     0.75
# rice krispies treats   1.25     0.25
# apple pie             10.00     4.00
# key lime pie           9.50     4.50

# %%
# Locate the Price of a torte and change the value
df.loc['torte',"Price"] = 11.5

# %%
# Inspect torte
df.loc['torte']
# Out:
# Student                                   Jade
# Packaging                Boxed (Clear Plastic)
# Price                                     11.5
# Expense                                    5.5
# Profit per Item                            5.0
# Quantity Sold (Day 1)                        0
# Quantity Sold (Day 2)                        5
# Quantity Sold (Day 3)                        7
# Quantity Sold (Day 4)                        7
# Name: torte, dtype: object

# %%
# Check the price of apple pie
price = df.loc['apple pie','Price']
price
# is the price greater than 5?
price > 5
# Out:
# True

# %%
# Is the price greater than 5? (for all rows)
df['Price'] > 5
# Out:
# Item
# brownie                 False
# cookie                  False
# cake                     True
# cupcake                 False
# fudge                   False
# banana bread            False
# torte                    True
# scone                   False
# muffin                  False
# rice krispies treats    False
# apple pie                True
# key lime pie             True
# Name: Price, dtype: bool

# %%
# Apply a boolean index to filter our data
df.loc[ df['Price'] > 5 ]
# Out:
#               Student              Packaging  Price  Expense  Profit per Item  \
# Item
# cake          Martina  Boxed (Clear Plastic)    9.5      5.0              4.5
# torte            Jade  Boxed (Clear Plastic)   11.5      5.5              5.0
# apple pie       Sally        Box (Cardboard)   10.0      4.0              6.0
# key lime pie  Martina        Box (Cardboard)    9.5      4.5              5.0
#
#               Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# Item
# cake                              1                      2
# torte                             0                      5
# apple pie                         0                      0
# key lime pie                      0                      0
#
#               Quantity Sold (Day 3)  Quantity Sold (Day 4)
# Item
# cake                              0                      0
# torte                             7                      7
# apple pie                         2                      3
# key lime pie                      3                      3

# %%
# Save the boolean index as a separate variable
filter_price = df["Price"] > 5
filter_price
# Out:
# Item
# brownie                 False
# cookie                  False
# cake                     True
# cupcake                 False
# fudge                   False
# banana bread            False
# torte                    True
# scone                   False
# muffin                  False
# rice krispies treats    False
# apple pie                True
# key lime pie             True
# Name: Price, dtype: bool

# %%
# Apply the filter to create a dataframe of selected values using square brackets
df_filtered = df[filter_price]
df_filtered
# Out:
#               Student              Packaging  Price  Expense  Profit per Item  \
# Item
# cake          Martina  Boxed (Clear Plastic)    9.5      5.0              4.5
# torte            Jade  Boxed (Clear Plastic)   11.5      5.5              5.0
# apple pie       Sally        Box (Cardboard)   10.0      4.0              6.0
# key lime pie  Martina        Box (Cardboard)    9.5      4.5              5.0
#
#               Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# Item
# cake                              1                      2
# torte                             0                      5
# apple pie                         0                      0
# key lime pie                      0                      0
#
#               Quantity Sold (Day 3)  Quantity Sold (Day 4)
# Item
# cake                              0                      0
# torte                             7                      7
# apple pie                         2                      3
# key lime pie                      3                      3

# %%
# Apply the filter to create a dataframe of selected values using .loc
df_filtered = df.loc[filter_price]
df_filtered
# Out:
#               Student              Packaging  Price  Expense  Profit per Item  \
# Item
# cake          Martina  Boxed (Clear Plastic)    9.5      5.0              4.5
# torte            Jade  Boxed (Clear Plastic)   11.5      5.5              5.0
# apple pie       Sally        Box (Cardboard)   10.0      4.0              6.0
# key lime pie  Martina        Box (Cardboard)    9.5      4.5              5.0
#
#               Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# Item
# cake                              1                      2
# torte                             0                      5
# apple pie                         0                      0
# key lime pie                      0                      0
#
#               Quantity Sold (Day 3)  Quantity Sold (Day 4)
# Item
# cake                              0                      0
# torte                             7                      7
# apple pie                         2                      3
# key lime pie                      3                      3

# %%
# Get the sum of True values for the filter
filter_price.sum()
# Out:
# 4

# %%
# Attempt to locate a value not in an index
df
# Out:
#                       Student                        Packaging  Price  \
# Item
# brownie                  Hugo  Individually Wrapped  (Plastic)   2.25
# cookie                  Sally  Individually Wrapped  (Plastic)   1.25
# cake                  Martina            Boxed (Clear Plastic)   9.50
# cupcake                   Joe                Boxed (Cardboard)   3.50
# fudge                    Hugo      Individually Wrapped (Foil)   3.00
# banana bread             Mark      Individually Wrapped (Foil)   2.75
# torte                    Jade            Boxed (Clear Plastic)  11.50
# scone                    Jade  Individually Wrapped  (Plastic)   2.00
# muffin                   Anne      Individually Wrapped (Foil)   1.50
# rice krispies treats  Martina  Individually Wrapped  (Plastic)   1.25
# apple pie               Sally                  Box (Cardboard)  10.00
# key lime pie          Martina                  Box (Cardboard)   9.50
#
#                       Expense  Profit per Item  Quantity Sold (Day 1)  \
# Item
# brownie                  0.25             2.00                     17
# cookie                   0.50             0.75                     40
# cake                     5.00             4.50                      1
# cupcake                  0.75             2.75                     10
# fudge                    1.00             2.00                      0
# banana bread             0.50             2.25                      0
# torte                    5.50             5.00                      0
# scone                    1.25             0.75                      0
# muffin                   0.75             0.75                      0
# rice krispies treats     0.25             1.00                      0
# apple pie                4.00             6.00                      0
# key lime pie             4.50             5.00                      0
#
#                       Quantity Sold (Day 2)  Quantity Sold (Day 3)  \
# Item
# brownie                                  19                     25
# cookie                                   32                     38
# cake                                      2                      0
# cupcake                                  14                     12
# fudge                                    20                     22
# banana bread                             10                     13
# torte                                     5                      7
# scone                                     8                     10
# muffin                                    3                      4
# rice krispies treats                      0                     10
# apple pie                                 0                      2
# key lime pie                              0                      3
#
#                       Quantity Sold (Day 4)
# Item
# brownie                                  25
# cookie                                   38
# cake                                      0
# cupcake                                  12
# fudge                                    22
# banana bread                             13
# torte                                     7
# scone                                    10
# muffin                                    4
# rice krispies treats                     30
# apple pie                                 3
# key lime pie                              3

# %%
# Create a filter for Packaging values that contain "individual"
filter_individual = df['Packaging'].str.contains('Individual')
# Apply the filter
df.loc[filter_individual]
df[~filter_individual]
# Out:
#               Student              Packaging  Price  Expense  Profit per Item  \
# Item
# cake          Martina  Boxed (Clear Plastic)    9.5     5.00             4.50
# cupcake           Joe      Boxed (Cardboard)    3.5     0.75             2.75
# torte            Jade  Boxed (Clear Plastic)   11.5     5.50             5.00
# apple pie       Sally        Box (Cardboard)   10.0     4.00             6.00
# key lime pie  Martina        Box (Cardboard)    9.5     4.50             5.00
#
#               Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# Item
# cake                              1                      2
# cupcake                          10                     14
# torte                             0                      5
# apple pie                         0                      0
# key lime pie                      0                      0
#
#               Quantity Sold (Day 3)  Quantity Sold (Day 4)
# Item
# cake                              0                      0
# cupcake                          12                     12
# torte                             7                      7
# apple pie                         2                      3
# key lime pie                      3                      3

# %%
# Create a filter for any index value that contains "pie"
filter_contains_pie = df.index.str.contains('pie')
# Apply the filter
df[filter_contains_pie]
# Out:
#                       Student                        Packaging  Price  \
# Item
# rice krispies treats  Martina  Individually Wrapped  (Plastic)   1.25
# apple pie               Sally                  Box (Cardboard)  10.00
# key lime pie          Martina                  Box (Cardboard)   9.50
#
#                       Expense  Profit per Item  Quantity Sold (Day 1)  \
# Item
# rice krispies treats     0.25              1.0                      0
# apple pie                4.00              6.0                      0
# key lime pie             4.50              5.0                      0
#
#                       Quantity Sold (Day 2)  Quantity Sold (Day 3)  \
# Item
# rice krispies treats                      0                     10
# apple pie                                 0                      2
# key lime pie                              0                      3
#
#                       Quantity Sold (Day 4)
# Item
# rice krispies treats                     30
# apple pie                                 3
# key lime pie                              3

# %%
# Create a filter for any index value that contains "pie"
filter_contains_pie = df.index.str.contains(' pie')
# Apply the filter
df[filter_contains_pie]
# Out:
#               Student        Packaging  Price  Expense  Profit per Item  \
# Item
# apple pie       Sally  Box (Cardboard)   10.0      4.0              6.0
# key lime pie  Martina  Box (Cardboard)    9.5      4.5              5.0
#
#               Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# Item
# apple pie                         0                      0
# key lime pie                      0                      0
#
#               Quantity Sold (Day 3)  Quantity Sold (Day 4)
# Item
# apple pie                         2                      3
# key lime pie                      3                      3

# %%
# Create a filter for Jade
filter_jade = df['Student']=='Jade'
filter_jade
# Out:
# Item
# brownie                 False
# cookie                  False
# cake                    False
# cupcake                 False
# fudge                   False
# banana bread            False
# torte                    True
# scone                    True
# muffin                  False
# rice krispies treats    False
# apple pie               False
# key lime pie            False
# Name: Student, dtype: bool

# %%
# Create a filter for Price
filter_price = df['Price'] > 5
filter_price
# Out:
# Item
# brownie                 False
# cookie                  False
# cake                     True
# cupcake                 False
# fudge                   False
# banana bread            False
# torte                    True
# scone                   False
# muffin                  False
# rice krispies treats    False
# apple pie                True
# key lime pie             True
# Name: Price, dtype: bool

# %%
# Combine the filters
filters_combined = filter_jade & filter_price
filters_combined
# Out:
# Item
# brownie                 False
# cookie                  False
# cake                    False
# cupcake                 False
# fudge                   False
# banana bread            False
# torte                    True
# scone                   False
# muffin                  False
# rice krispies treats    False
# apple pie               False
# key lime pie            False
# dtype: bool

# %%
# Apply the combined filter
df.loc[filters_combined]
# Out:
#       Student              Packaging  Price  Expense  Profit per Item  \
# Item
# torte    Jade  Boxed (Clear Plastic)   11.5      5.5              5.0
#
#        Quantity Sold (Day 1)  Quantity Sold (Day 2)  Quantity Sold (Day 3)  \
# Item
# torte                      0                      5                      7
#
#        Quantity Sold (Day 4)
# Item
# torte                      7

# %%
# Create a new filter for less than 2
filter_price_less = df['Price'] < 2
# Combine the filters
df.loc[ filter_price_less & filter_jade]
# Out:
# Empty DataFrame
# Columns: [Student, Packaging, Price, Expense, Profit per Item, Quantity Sold (Day 1), Quantity Sold (Day 2), Quantity Sold (Day 3), Quantity Sold (Day 4)]
# Index: []

# %%
# List of students
students = ["Tom","Anne",'Martin', "Jose",'Sally']

# %%
# Creating a filter for any student in the list
df['Student'].isin(students)
# Out:
# Item
# brownie                 False
# cookie                   True
# cake                    False
# cupcake                 False
# fudge                   False
# banana bread            False
# torte                   False
# scone                   False
# muffin                   True
# rice krispies treats    False
# apple pie                True
# key lime pie            False
# Name: Student, dtype: bool

# %%
# Apply the filter
df[df['Student'].isin(students)]
# Out:
#           Student                        Packaging  Price  Expense  \
# Item
# cookie      Sally  Individually Wrapped  (Plastic)   1.25     0.50
# muffin       Anne      Individually Wrapped (Foil)   1.50     0.75
# apple pie   Sally                  Box (Cardboard)  10.00     4.00
#
#            Profit per Item  Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# Item
# cookie                0.75                     40                     32
# muffin                0.75                      0                      3
# apple pie             6.00                      0                      0
#
#            Quantity Sold (Day 3)  Quantity Sold (Day 4)
# Item
# cookie                        38                     38
# muffin                         4                      4
# apple pie                      2                      3

# %%
# This filepath will work if you saved your file in the recommend folder structure
fname = "/content/drive/MyDrive/CodingDojo/01-Fundamentals/Week02/Data/bake-sale-data.csv"
df = pd.read_csv(fname)
df.head()
# Out:
#       Item  Student                        Packaging  Price  Expense  \
# 0  brownie     Hugo  Individually Wrapped  (Plastic)   2.25     0.25
# 1   cookie    Sally  Individually Wrapped  (Plastic)   1.25     0.50
# 2     cake  Martina            Boxed (Clear Plastic)   9.50     5.00
# 3  cupcake      Joe                Boxed (Cardboard)   3.50     0.75
# 4    fudge     Hugo      Individually Wrapped (Foil)   3.00     1.00
#
#    Profit per Item  Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# 0             2.00                     17                     19
# 1             0.75                     40                     32
# 2             4.50                      1                      2
# 3             2.75                     10                     14
# 4             2.00                      0                     20
#
#    Quantity Sold (Day 3)  Quantity Sold (Day 4)
# 0                     25                     25
# 1                     38                     38
# 2                      0                      0
# 3                     12                     12
# 4                     22                     22

# %%
df
# Out:
#                     Item  Student                        Packaging  Price  \
# 0                brownie     Hugo  Individually Wrapped  (Plastic)   2.25
# 1                 cookie    Sally  Individually Wrapped  (Plastic)   1.25
# 2                   cake  Martina            Boxed (Clear Plastic)   9.50
# 3                cupcake      Joe                Boxed (Cardboard)   3.50
# 4                  fudge     Hugo      Individually Wrapped (Foil)   3.00
# 5           banana bread     Mark      Individually Wrapped (Foil)   2.75
# 6                  torte     Jade            Boxed (Clear Plastic)  10.50
# 7                  scone     Jade  Individually Wrapped  (Plastic)   2.00
# 8                 muffin     Anne      Individually Wrapped (Foil)   1.50
# 9   rice krispies treats  Martina  Individually Wrapped  (Plastic)   1.25
# 10             apple pie    Sally                  Box (Cardboard)  10.00
# 11          key lime pie  Martina                  Box (Cardboard)   9.50
#
#     Expense  Profit per Item  Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# 0      0.25             2.00                     17                     19
# 1      0.50             0.75                     40                     32
# 2      5.00             4.50                      1                      2
# 3      0.75             2.75                     10                     14
# 4      1.00             2.00                      0                     20
# 5      0.50             2.25                      0                     10
# 6      5.50             5.00                      0                      5
# 7      1.25             0.75                      0                      8
# 8      0.75             0.75                      0                      3
# 9      0.25             1.00                      0                      0
# 10     4.00             6.00                      0                      0
# 11     4.50             5.00                      0                      0
#
#     Quantity Sold (Day 3)  Quantity Sold (Day 4)
# 0                      25                     25
# 1                      38                     38
# 2                       0                      0
# 3                      12                     12
# 4                      22                     22
# 5                      13                     13
# 6                       7                      7
# 7                      10                     10
# 8                       4                      4
# 9                      10                     30
# 10                      2                      3
# 11                      3                      3

# %%
# Get the unique values and their count for the Student column
df["Student"].value_counts()
# Out:
# Martina    3
# Hugo       2
# Sally      2
# Jade       2
# Joe        1
# Mark       1
# Anne       1
# Name: Student, dtype: int64

# %%
# Use normalize = True to output a ratio
df["Student"].value_counts(normalize=True)
# Out:
# Martina    0.250000
# Hugo       0.166667
# Sally      0.166667
# Jade       0.166667
# Joe        0.083333
# Mark       0.083333
# Anne       0.083333
# Name: Student, dtype: float64

# %%
# select quantity columns using .str.contains
columns = df.columns
filter_quantity_cols = columns[columns.str.contains('Quantity')]
filter_quantity_cols
# Out:
# Index(['Quantity Sold (Day 1)', 'Quantity Sold (Day 2)',
#        'Quantity Sold (Day 3)', 'Quantity Sold (Day 4)'],
#       dtype='object')

# %%
# Use the filter_quantity_cols index to limit the dataframe to Quantity columns
df[filter_quantity_cols]
# Out:
#                       Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# Item
# brownie                                  17                     19
# cookie                                   40                     32
# cake                                      1                      2
# cupcake                                  10                     14
# fudge                                     0                     20
# banana bread                              0                     10
# torte                                     0                      5
# scone                                     0                      8
# muffin                                    0                      3
# rice krispies treats                      0                      0
# apple pie                                 0                      0
# key lime pie                              0                      0
#
#                       Quantity Sold (Day 3)  Quantity Sold (Day 4)
# Item
# brownie                                  25                     25
# cookie                                   38                     38
# cake                                      0                      0
# cupcake                                  12                     12
# fudge                                    22                     22
# banana bread                             13                     13
# torte                                     7                      7
# scone                                    10                     10
# muffin                                    4                      4
# rice krispies treats                     10                     30
# apple pie                                 2                      3
# key lime pie                              3                      3

# %%
# Obtain the sum of the values in each column
df[filter_quantity_cols].sum()
# Out:
# Quantity Sold (Day 1)     68
# Quantity Sold (Day 2)    113
# Quantity Sold (Day 3)    146
# Quantity Sold (Day 4)    167
# dtype: int64

# %%
# Obtain the sum across rows
df[filter_quantity_cols].sum(axis=1)
# Out:
# 0      86
# 1     148
# 2       3
# 3      48
# 4      64
# 5      36
# 6      19
# 7      28
# 8      11
# 9      40
# 10      5
# 11      6
# dtype: int64

# %%
# Add a column to include the cumulative quantity
df['Cumulative Quantity (Day 4)'] = df[filter_quantity_cols].sum(axis=1)
df.head()
# Out:
#       Item  Student                        Packaging  Price  Expense  \
# 0  brownie     Hugo  Individually Wrapped  (Plastic)   2.25     0.25
# 1   cookie    Sally  Individually Wrapped  (Plastic)   1.25     0.50
# 2     cake  Martina            Boxed (Clear Plastic)   9.50     5.00
# 3  cupcake      Joe                Boxed (Cardboard)   3.50     0.75
# 4    fudge     Hugo      Individually Wrapped (Foil)   3.00     1.00
#
#    Profit per Item  Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# 0             2.00                     17                     19
# 1             0.75                     40                     32
# 2             4.50                      1                      2
# 3             2.75                     10                     14
# 4             2.00                      0                     20
#
#    Quantity Sold (Day 3)  Quantity Sold (Day 4)  Cumulative Quantity (Day 4)
# 0                     25                     25                           86
# 1                     38                     38                          148
# 2                      0                      0                            3
# 3                     12                     12                           48
# 4                     22                     22                           64

# %%
df.columns
# Out:
# Index(['Student', 'Packaging', 'Price', 'Expense', 'Quantity Sold (Day 1)',
#        'Quantity Sold (Day 2)', 'Quantity Sold (Day 3)',
#        'Quantity Sold (Day 4)', 'Cumulative Quantity (Day 4)'],
#       dtype='object')

# %%
# Add a column to include the cumulative quantity
df['Cumulative Quantity (Day 4)'] = df[filter_quantity_cols].sum(axis=1)
df.head()
# Out:
#          Student                        Packaging  Price  Expense  \
# Item
# brownie     Hugo  Individually Wrapped  (Plastic)   2.25     0.25
# cookie     Sally  Individually Wrapped  (Plastic)   1.25     0.50
# cake     Martina            Boxed (Clear Plastic)   9.50     5.00
# cupcake      Joe                Boxed (Cardboard)   3.50     0.75
# fudge       Hugo      Individually Wrapped (Foil)   3.00     1.00
#
#          Quantity Sold (Day 1)  Quantity Sold (Day 2)  Quantity Sold (Day 3)  \
# Item
# brownie                     17                     19                     25
# cookie                      40                     32                     38
# cake                         1                      2                      0
# cupcake                     10                     14                     12
# fudge                        0                     20                     22
#
#          Quantity Sold (Day 4)  Cumulative Quantity (Day 4)
# Item
# brownie                     25                           86
# cookie                      38                          148
# cake                         0                            3
# cupcake                     12                           48
# fudge                       22                           64

# %%
df['Cumulative Quantity (Day 4)'].sort_values(ascending=False)
# Out:
# Item
# cookie                  148
# brownie                  86
# fudge                    64
# cupcake                  48
# rice krispies treats     40
# banana bread             36
# scone                    28
# torte                    19
# muffin                   11
# key lime pie              6
# apple pie                 5
# cake                      3
# Name: Cumulative Quantity (Day 4), dtype: int64

# %%
df['total profit'] = df['Cumulative Quantity (Day 4)'] * df['Profit per Item']

# %%
df
# Out:
#                       Student                        Packaging  Price  \
# Item
# brownie                  Hugo  Individually Wrapped  (Plastic)   2.25
# cookie                  Sally  Individually Wrapped  (Plastic)   1.25
# cake                  Martina            Boxed (Clear Plastic)   9.50
# cupcake                   Joe                Boxed (Cardboard)   3.50
# fudge                    Hugo      Individually Wrapped (Foil)   3.00
# banana bread             Mark      Individually Wrapped (Foil)   2.75
# torte                    Jade            Boxed (Clear Plastic)  10.50
# scone                    Jade  Individually Wrapped  (Plastic)   2.00
# muffin                   Anne      Individually Wrapped (Foil)   1.50
# rice krispies treats  Martina  Individually Wrapped  (Plastic)   1.25
# apple pie               Sally                  Box (Cardboard)  10.00
# key lime pie          Martina                  Box (Cardboard)   9.50
#
#                       Expense  Quantity Sold (Day 1)  Profit per Item  \
# Item
# brownie                  0.25                     17             2.00
# cookie                   0.50                     40             0.75
# cake                     5.00                      1             4.50
# cupcake                  0.75                     10             2.75
# fudge                    1.00                      0             2.00
# banana bread             0.50                      0             2.25
# torte                    5.50                      0             5.00
# scone                    1.25                      0             0.75
# muffin                   0.75                      0             0.75
# rice krispies treats     0.25                      0             1.00
# apple pie                4.00                      0             6.00
# key lime pie             4.50                      0             5.00
#
#                       Quantity Sold (Day 2)  Quantity Sold (Day 3)  \
# Item
# brownie                                  19                     25
# cookie                                   32                     38
# cake                                      2                      0
# cupcake                                  14                     12
# fudge                                    20                     22
# banana bread                             10                     13
# torte                                     5                      7
# scone                                     8                     10
# muffin                                    3                      4
# rice krispies treats                      0                     10
# apple pie                                 0                      2
# key lime pie                              0                      3
#
#                       Quantity Sold (Day 4)  Cumulative Quantity (Day 4)  \
# Item
# brownie                                  25                           86
# cookie                                   38                          148
# cake                                      0                            3
# cupcake                                  12                           48
# fudge                                    22                           64
# banana bread                             13                           36
# torte                                     7                           19
# scone                                    10                           28
# muffin                                    4                           11
# rice krispies treats                     30                           40
# apple pie                                 3                            5
# key lime pie                              3                            6
#
#                       total profit
# Item
# brownie                     172.00
# cookie                      111.00
# cake                         13.50
# cupcake                     132.00
# fudge                       128.00
# banana bread                 81.00
# torte                        95.00
# scone                        21.00
# muffin                        8.25
# rice krispies treats         40.00
# apple pie                    30.00
# key lime pie                 30.00

# %%
df = df.rename(columns={'total profit': 'Cumulative Profit (Day 4)'})

# %%
df['Cumulative Profit (Day 4)'].sort_values(ascending=False)
# Out:
# Item
# brownie                 172.00
# cupcake                 132.00
# fudge                   128.00
# cookie                  111.00
# torte                    95.00
# banana bread             81.00
# rice krispies treats     40.00
# apple pie                30.00
# key lime pie             30.00
# scone                    21.00
# cake                     13.50
# muffin                    8.25
# Name: Cumulative Profit (Day 4), dtype: float64

# %%
# groupby needs an aggregation functon
student_sums = df.groupby("Student").sum()
student_sums
# Out:
# <ipython-input-48-7ca0251851d8>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   student_sums = df.groupby("Student").sum()
#          Price  Expense  Quantity Sold (Day 1)  Profit per Item  \
# Student
# Anne      1.50     0.75                      0             0.75
# Hugo      5.25     1.25                     17             4.00
# Jade     12.50     6.75                      0             5.75
# Joe       3.50     0.75                     10             2.75
# Mark      2.75     0.50                      0             2.25
# Martina  20.25     9.75                      1            10.50
# Sally    11.25     4.50                     40             6.75
#
#          Quantity Sold (Day 2)  Quantity Sold (Day 3)  Quantity Sold (Day 4)  \
# Student
# Anne                         3                      4                      4
# Hugo                        39                     47                     47
# Jade                        13                     17                     17
# Joe                         14                     12                     12
# Mark                        10                     13                     13
# Martina                      2                     13                     33
# Sally                       32                     40                     41
#
#          Cumulative Quantity (Day 4)  Cumulative Profit (Day 4)
# Student
# Anne                              11                       8.25
# Hugo                             150                     300.00
# Jade                              47                     116.00
# Joe                               48                     132.00
# Mark                              36                      81.00
# Martina                           49                      83.50
# Sally                            153                     141.00

# %%
# Obtain the cumulative profit per student
quantity_by_student = df.groupby('Student')['Cumulative Quantity (Day 4)'].sum()
# Sort from highest to lowest profit
quantity_by_student.sort_values(ascending=False)
# Out:
# Student
# Sally      153
# Hugo       150
# Martina     49
# Joe         48
# Jade        47
# Mark        36
# Anne        11
# Name: Cumulative Quantity (Day 4), dtype: int64

# %%
# Obtain the cumulative profit per student
quantity_by_student = df.groupby('Student')['Cumulative Profit (Day 4)'].sum()
# Sort from highest to lowest profit
quantity_by_student.sort_values(ascending=False)
# Out:
# Student
# Hugo       300.00
# Sally      141.00
# Joe        132.00
# Jade       116.00
# Martina     83.50
# Mark        81.00
# Anne         8.25
# Name: Cumulative Profit (Day 4), dtype: float64

# %%
df["Cumulative Profit (Day 4)"].sum()-1000
# Out:
# -138.25
