# %% [markdown]
# <a href="https://colab.research.google.com/github/hekmat-ashqer/data_science_basics/blob/main/kagle_assignment_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# path for the insurance csv file
file_path = '/content/drive/MyDrive/CodingDojo/01-Fundamentals/Week02/Lectures/NFLX.csv'

# load csv file as data frame

netflix_df = pd.read_csv(file_path)
netflix_df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-02-01  353.859985  365.390015  349.910004  361.989990  361.989990
# 1    2023-02-02  365.160004  368.320007  358.429993  366.890015  366.890015
# 2    2023-02-03  359.079987  379.429993  359.000000  365.899994  365.899994
# 3    2023-02-06  363.640015  368.450012  360.679993  361.480011  361.480011
# 4    2023-02-07  358.510010  364.179993  354.179993  362.950012  362.950012
# ..          ...         ...         ...         ...         ...         ...
# 246  2024-01-25  551.950012  563.460022  548.460022  562.000000  562.000000
# 247  2024-01-26  561.809998  579.640015  558.429993  570.419983  570.419983
# 248  2024-01-29  571.349976  578.549988  562.679993  575.789978  575.789978
# 249  2024-01-30  567.320007  570.880005  560.820007  562.849976  562.849976
# 250  2024-01-31  562.849976  572.150024  562.039978  564.109985  564.109985
#
#        Volume
# 0     8005200
# 1     7857000
# ...

# %%
netflix_df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   404.181354  409.754742  398.958446  404.270478  404.270478
# std     60.849872   61.318707   60.722608   61.193722   61.193722
# min    287.339996  297.450012  285.329987  292.760010  292.760010
# 25%    348.994995  356.860001  344.490005  348.119995  348.119995
# 50%    412.000000  418.839996  407.399994  411.690002  411.690002
# 75%    444.729996  448.574997  439.175003  444.944992  444.944992
# max    571.349976  579.640015  562.679993  575.789978  575.789978
#
#              Volume
# count  2.510000e+02
# mean   6.135308e+06
# std    3.814621e+06
# min    1.404700e+06
# 25%    3.966000e+06
# 50%    5.128900e+06
# 75%    6.880600e+06
# max    2.807440e+07

# %%
# Filter columns based on numerical data types (int or float)
numerical_columns = netflix_df.select_dtypes(include=['int', 'float'])

# Count the number of numerical columns
numerical_column_count = len(numerical_columns.columns)
numerical_column_count
# Out:
# 6

# %%
# Filter columns based on object or category data types (categorical data)
categorical_columns = netflix_df.select_dtypes(include=['object', 'category'])

# Count the number of categorical columns
categorical_column_count = len(categorical_columns.columns)
categorical_column_count
# Out:
# 1

# %%
column_median = netflix_df.median()
column_median
# Out:
# <ipython-input-10-098add65426f>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   column_median = netflix_df.median()
# Open         4.120000e+02
# High         4.188400e+02
# Low          4.074000e+02
# Close        4.116900e+02
# Adj Close    4.116900e+02
# Volume       5.128900e+06
# dtype: float64

# %%
#column_means = round(netflix_df.mean(),2)
column_means = round(netflix_df.mean(),2)
column_means
# Out:
# <ipython-input-13-cb36fd74b9e4>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   column_means = round(netflix_df.mean(),2)
# Open             404.18
# High             409.75
# Low              398.96
# Close            404.27
# Adj Close        404.27
# Volume       6135307.97
# dtype: float64

# %%
column_count = netflix_df.value_counts()
column_count
# Out:
# Date        Open        High        Low         Close       Adj Close   Volume
# 2023-02-01  353.859985  365.390015  349.910004  361.989990  361.989990  8005200     1
# 2023-10-09  378.049988  387.170013  377.760010  385.950012  385.950012  3299800     1
# 2023-09-20  397.049988  397.989990  386.119995  386.299988  386.299988  3866600     1
# 2023-09-21  386.500000  395.899994  383.420013  384.149994  384.149994  5547900     1
# 2023-09-22  385.000000  386.880005  378.359985  379.809998  379.809998  3692800     1
#                                                                                    ..
# 2023-06-08  399.769989  409.540009  396.339996  409.369995  409.369995  5991100     1
# 2023-06-09  424.500000  425.899994  414.760010  420.019989  420.019989  12363000    1
# 2023-06-12  418.829987  424.700012  416.570007  423.970001  423.970001  5959500     1
# 2023-06-13  430.010010  437.269989  428.399994  435.730011  435.730011  7820500     1
# ...

# %%
# Convert the 'Date' column to datetime
netflix_df['Date'] = pd.to_datetime(netflix_df['Date'])

# Group by month and calculate the sum of 'Value' for each month
monthly_data = netflix_df.groupby(netflix_df['Date'].dt.to_period('M')).mean()



monthly_data
# Out:
# <ipython-input-18-d529581660c9>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   monthly_data = netflix_df.groupby(netflix_df['Date'].dt.to_period('M')).mean()
#                Open        High         Low       Close   Adj Close  \
# Date
# 2023-02  349.309474  354.905265  343.967367  349.097894  349.097894
# 2023-03  312.412607  318.216088  307.388696  312.603046  312.603046
# 2023-04  334.085260  337.574738  329.006317  333.743683  333.743683
# 2023-05  345.423635  352.251365  341.192728  347.460003  347.460003
# 2023-06  421.298094  428.052855  416.226191  421.458093  421.458093
# 2023-07  439.396500  445.094499  432.811000  440.328000  440.328000
# 2023-08  424.249565  430.176084  418.849129  424.058697  424.058697
# 2023-09  410.146500  414.349002  404.209000  407.321997  407.321997
# ...
